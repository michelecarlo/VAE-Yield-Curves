# %%
import torch
import torch.nn as nn

import numpy as np

from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import random

# %% [markdown]
# ### VAE architecture

# %%
class Encoder(nn.Module):
    
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(Encoder, self).__init__()

        self.FC_input = nn.Linear(input_dim, hidden_dim)
        self.FC_input2 = nn.Linear(hidden_dim, latent_dim)
        
        self.LeakyReLU = nn.LeakyReLU(0.2)
        
        self.training = True
        
    def forward(self, x):
        h_       = self.LeakyReLU(self.FC_input(x))
        latent   = self.LeakyReLU(self.FC_input2(h_))
        
        return latent

# %%
class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_dim):
        super(Decoder, self).__init__()
        self.FC_hidden = nn.Linear(latent_dim, hidden_dim)
        self.FC_hidden2 = nn.Linear(hidden_dim, hidden_dim)
        self.FC_output = nn.Linear(hidden_dim, output_dim)
        
        self.LeakyReLU = nn.LeakyReLU(0.2)
        
    def forward(self, x):
        h     = self.LeakyReLU(self.FC_hidden(x))
        h     = self.LeakyReLU(self.FC_hidden2(h))
        
        x_hat = self.FC_output(h)
        return x_hat

# %%
class Model(nn.Module):
    def __init__(self, Encoder, Decoder):
        super(Model, self).__init__()
        self.Encoder = Encoder
        self.Decoder = Decoder
                  
    def forward(self, x):
        latent = self.Encoder(x)
        x_hat  = self.Decoder(latent)
        
        return x_hat

# %%
# Set seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

cuda = False
DEVICE = torch.device("cuda" if cuda else "cpu")

batch_size = 100

x_dim  = 11
hidden_dim = 7
latent_dim = 3

lr = 1e-3

epochs = 10#0

# %%
encoder = Encoder(input_dim=x_dim, hidden_dim=hidden_dim, latent_dim=latent_dim)
decoder = Decoder(latent_dim=latent_dim, hidden_dim = hidden_dim, output_dim = x_dim)

model = Model(Encoder=encoder, Decoder=decoder).to(DEVICE)

# %% [markdown]
# ### Loss function

# %%
from torch.optim import Adam

BCE_loss = nn.BCELoss()

def loss_function(x, x_hat):
    reconstruction_loss = nn.functional.mse_loss(x_hat, x, reduction='mean')
    return reconstruction_loss


optimizer = Adam(model.parameters(), lr=lr)

# %% [markdown]
# ### Datasets

# %%
df = pd.read_csv('Us_daily.csv', index_col=0, parse_dates=True)
df.index = pd.to_datetime(df.index)

#Exclude NaN columns and rows
df = df[df.index >= '2002-01-01']
df = df.drop(columns=['2 Mo', '4 Mo'])
df = df.dropna(axis=0, how='any')

tenors  = df.columns.tolist()

df_diff = df.copy()
df_diff['6 Mo diff'] = df['6 Mo'].shift(1) - df['6 Mo']

print(df.head())
print(df.isnull().any().any())
# Out:
# C:\Users\miche\AppData\Local\Temp\ipykernel_58276\2522163714.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('Us_daily.csv', index_col=0, parse_dates=True)
#             1 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  \
# Date
# 2023-12-29  5.60  5.40  5.26  4.79  4.23  4.01  3.84  3.88   3.88   4.20
# 2023-12-28  5.57  5.45  5.28  4.82  4.26  4.02  3.83  3.84   3.84   4.14
# 2023-12-27  5.55  5.44  5.26  4.79  4.20  3.97  3.78  3.81   3.79   4.10
# 2023-12-26  5.53  5.45  5.28  4.83  4.26  4.05  3.89  3.91   3.89   4.20
# 2023-12-22  5.54  5.44  5.31  4.82  4.31  4.04  3.87  3.92   3.90   4.21
#
#             30 Yr
# Date
# 2023-12-29   4.03
# 2023-12-28   3.98
# 2023-12-27   3.95
# 2023-12-26   4.04
# 2023-12-22   4.05
# False

# %%
print(df_diff.head())
print(df_diff.isnull().any().any())
# Out:
#             1 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  \
# Date
# 2023-12-29  5.60  5.40  5.26  4.79  4.23  4.01  3.84  3.88   3.88   4.20
# 2023-12-28  5.57  5.45  5.28  4.82  4.26  4.02  3.83  3.84   3.84   4.14
# 2023-12-27  5.55  5.44  5.26  4.79  4.20  3.97  3.78  3.81   3.79   4.10
# 2023-12-26  5.53  5.45  5.28  4.83  4.26  4.05  3.89  3.91   3.89   4.20
# 2023-12-22  5.54  5.44  5.31  4.82  4.31  4.04  3.87  3.92   3.90   4.21
#
#             30 Yr  6 Mo diff
# Date
# 2023-12-29   4.03        NaN
# 2023-12-28   3.98      -0.02
# 2023-12-27   3.95       0.02
# 2023-12-26   4.04      -0.02
# 2023-12-22   4.05      -0.03
# True

# %%
# Normalize the data
X = df.values
'''scaler = StandardScaler()
X = scaler.fit_transform(X)'''

# Split the data into training and test sets, then convert to PyTorch tensors
X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
X_train_tensor = TensorDataset(X_train_tensor)
X_test_tensor = TensorDataset(X_test_tensor)

# %%
kwargs = {'num_workers': 1} # , 'pin_memory': True

train_loader = DataLoader(dataset=X_train_tensor, batch_size=batch_size, shuffle=True, drop_last=True, **kwargs)
test_loader  = DataLoader(dataset=X_test_tensor,  batch_size=batch_size, shuffle=False, drop_last=True, **kwargs)

# %%
print("Start training AE...")
model.train()

for epoch in range(epochs):
    overall_loss = 0
    for batch_idx, (x,) in enumerate(train_loader):
        x = x.view(batch_size, x_dim)
        x = x.to(DEVICE)

        optimizer.zero_grad()

        x_hat = model(x)
        loss = loss_function(x, x_hat)
        
        overall_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        
    print("\tEpoch", epoch + 1, "complete!", "\tAverage Loss: ", overall_loss / (batch_idx*batch_size))
    
print("Finish!!")
# Out:
# Start training AE...
# 	Epoch 1 complete! 	Average Loss:  0.07354484748840331
# 	Epoch 2 complete! 	Average Loss:  0.06933503137316023
# 	Epoch 3 complete! 	Average Loss:  0.05408999933515276
# 	Epoch 4 complete! 	Average Loss:  0.02413184663227626
# 	Epoch 5 complete! 	Average Loss:  0.01123251644202641
# 	Epoch 6 complete! 	Average Loss:  0.008454583474567958
# 	Epoch 7 complete! 	Average Loss:  0.00780277955532074
# 	Epoch 8 complete! 	Average Loss:  0.007572100179536002
# 	Epoch 9 complete! 	Average Loss:  0.0074401630163192746
# 	Epoch 10 complete! 	Average Loss:  0.007332140820366996
# 	Epoch 11 complete! 	Average Loss:  0.007212011677878244
# 	Epoch 12 complete! 	Average Loss:  0.007105830601283482
# 	Epoch 13 complete! 	Average Loss:  0.006996464439800808
# 	Epoch 14 complete! 	Average Loss:  0.0068717719146183555
# 	Epoch 15 complete! 	Average Loss:  0.006769252760069711
# 	Epoch 16 complete! 	Average Loss:  0.006643467630658831
# 	Epoch 17 complete! 	Average Loss:  0.006512602022715978
# 	Epoch 18 complete! 	Average Loss:  0.006387036051068987
# 	Epoch 19 complete! 	Average Loss:  0.0062524024503571645
# 	Epoch 20 complete! 	Average Loss:  0.00612040080342974
# 	Epoch 21 complete! 	Average Loss:  0.0059726990801947455
# 	Epoch 22 complete! 	Average Loss:  0.005836377646241869
# 	Epoch 23 complete! 	Average Loss:  0.005676636244569506
# 	Epoch 24 complete! 	Average Loss:  0.005519766398838588
# 	Epoch 25 complete! 	Average Loss:  0.005363155969551631
# 	Epoch 26 complete! 	Average Loss:  0.0051849163004330226
# 	Epoch 27 complete! 	Average Loss:  0.0049999642372131345
# 	Epoch 28 complete! 	Average Loss:  0.004802829435893468
# 	Epoch 29 complete! 	Average Loss:  0.0046004119515419
# 	Epoch 30 complete! 	Average Loss:  0.004373910307884216
# 	Epoch 31 complete! 	Average Loss:  0.004152532568999699
# 	Epoch 32 complete! 	Average Loss:  0.0039430221404348105
# 	Epoch 33 complete! 	Average Loss:  0.0037149947711399623
# 	Epoch 34 complete! 	Average Loss:  0.0034961797297000884
# 	Epoch 35 complete! 	Average Loss:  0.0032940586805343627
# 	Epoch 36 complete! 	Average Loss:  0.0030859222412109376
# 	Epoch 37 complete! 	Average Loss:  0.0028855776829378945
# 	Epoch 38 complete! 	Average Loss:  0.002690675743988582
# 	Epoch 39 complete! 	Average Loss:  0.0024778536004679544
# 	Epoch 40 complete! 	Average Loss:  0.0022686636447906494
# 	Epoch 41 complete! 	Average Loss:  0.0020521255603858403
# 	Epoch 42 complete! 	Average Loss:  0.0018362677608217512
# 	Epoch 43 complete! 	Average Loss:  0.001624078705906868
# 	Epoch 44 complete! 	Average Loss:  0.0014341139857258116
# 	Epoch 45 complete! 	Average Loss:  0.001278218116079058
# 	Epoch 46 complete! 	Average Loss:  0.0011549530412469592
# 	Epoch 47 complete! 	Average Loss:  0.0010481269700186593
# 	Epoch 48 complete! 	Average Loss:  0.0009602927246264048
# 	Epoch 49 complete! 	Average Loss:  0.0008802218820367541
# 	Epoch 50 complete! 	Average Loss:  0.0008126130700111389
# 	Epoch 51 complete! 	Average Loss:  0.0007481500187090465
# 	Epoch 52 complete! 	Average Loss:  0.000694917659674372
# 	Epoch 53 complete! 	Average Loss:  0.0006439039324011122
# 	Epoch 54 complete! 	Average Loss:  0.000597984322479793
# 	Epoch 55 complete! 	Average Loss:  0.0005581696129270962
# 	Epoch 56 complete! 	Average Loss:  0.0005240656765443938
# 	Epoch 57 complete! 	Average Loss:  0.0004921679220029286
# 	Epoch 58 complete! 	Average Loss:  0.00046583189176661627
# 	Epoch 59 complete! 	Average Loss:  0.00044331664059843337
# 	Epoch 60 complete! 	Average Loss:  0.00042290686709540234
# 	Epoch 61 complete! 	Average Loss:  0.00040542348474264145
# 	Epoch 62 complete! 	Average Loss:  0.00039080657277788437
# 	Epoch 63 complete! 	Average Loss:  0.0003786866297679288
# 	Epoch 64 complete! 	Average Loss:  0.00036876649143440383
# 	Epoch 65 complete! 	Average Loss:  0.0003590277736740453
# 	Epoch 66 complete! 	Average Loss:  0.0003517773417489869
# 	Epoch 67 complete! 	Average Loss:  0.00034488044306635855
# 	Epoch 68 complete! 	Average Loss:  0.0003397021054157189
# 	Epoch 69 complete! 	Average Loss:  0.00033480243810585567
# 	Epoch 70 complete! 	Average Loss:  0.00033049089621220315
# 	Epoch 71 complete! 	Average Loss:  0.00032672221160360746
# 	Epoch 72 complete! 	Average Loss:  0.0003230587760252612
# 	Epoch 73 complete! 	Average Loss:  0.00031993831587689265
# 	Epoch 74 complete! 	Average Loss:  0.00031765029951930047
# 	Epoch 75 complete! 	Average Loss:  0.00031495054917676107
# 	Epoch 76 complete! 	Average Loss:  0.00031252156251243183
# 	Epoch 77 complete! 	Average Loss:  0.0003102463829730238
# 	Epoch 78 complete! 	Average Loss:  0.00030783189833164215
# 	Epoch 79 complete! 	Average Loss:  0.00030570041281836375
# 	Epoch 80 complete! 	Average Loss:  0.00030422413774899073
# 	Epoch 81 complete! 	Average Loss:  0.00030221301636525563
# 	Epoch 82 complete! 	Average Loss:  0.00030067133318100657
# 	Epoch 83 complete! 	Average Loss:  0.00029888283301677024
# 	Epoch 84 complete! 	Average Loss:  0.0002975982805447919
# 	Epoch 85 complete! 	Average Loss:  0.00029570083745888303
# 	Epoch 86 complete! 	Average Loss:  0.00029402248987129756
# 	Epoch 87 complete! 	Average Loss:  0.0002929568487618651
# 	Epoch 88 complete! 	Average Loss:  0.0002922793616141592
# 	Epoch 89 complete! 	Average Loss:  0.00029042096808552743
# 	Epoch 90 complete! 	Average Loss:  0.0002894681479249682
# 	Epoch 91 complete! 	Average Loss:  0.0002886121549776622
# 	Epoch 92 complete! 	Average Loss:  0.00028770025287355695
# 	Epoch 93 complete! 	Average Loss:  0.00028656169665711265
# 	Epoch 94 complete! 	Average Loss:  0.0002854163338031088
# 	Epoch 95 complete! 	Average Loss:  0.00028438658959099226
# 	Epoch 96 complete! 	Average Loss:  0.0002840700756226267
# 	Epoch 97 complete! 	Average Loss:  0.00028217839343207225
# 	Epoch 98 complete! 	Average Loss:  0.0002825390882790089
# 	Epoch 99 complete! 	Average Loss:  0.0002814042435160705
# 	Epoch 100 complete! 	Average Loss:  0.00028142873463886126
# Finish!!

# %% [markdown]
# ### Inference

# %%
model.eval()

'''with torch.no_grad():
    for batch_idx, (x, ) in enumerate(tqdm(test_loader)):
        x = x.view(batch_size, x_dim).to(DEVICE)
        
        x_hat = model(x)'''
with torch.no_grad():
    x_test = torch.tensor(X_test, dtype=torch.float32).to(DEVICE)
    x_hat = model(x_test)

# %%
def plot_curve(x, idx):
    plt.plot(x[idx].numpy(), color = 'blue', label='Original')
    plt.plot(x_hat[idx].numpy(), color = 'red', linestyle = '--',label='Reconstruction')
    plt.title(f'Original vs Reconstruction for Sample {idx}')
    plt.xlabel('Tenors')
    plt.xticks(ticks=range(len(tenors)), labels=tenors, rotation=45)
    plt.legend()
    plt.show()

# %%
plot_curve(x_test, 1)
plot_curve(x_test, 10)
plot_curve(x_test, 40)
plot_curve(x_test, 400)

# %%
# Perform PCA
pca = PCA(n_components=3)  # Reduce to 2 principal components
pca.fit(X)  # Fit PCA to the original dataset

# Extract eigenvectors (principal components)
eigenvectors = pca.components_

# Plot eigenvectors
plt.figure(figsize=(10, 6))
for i, eigenvector in enumerate(eigenvectors):
    plt.plot(eigenvector, label=f'Principal Component {i + 1}')

plt.title("Eigenvectors of Principal Components")
plt.xlabel("Tenors")
plt.xticks(ticks=range(len(tenors)), labels=tenors, rotation=45)
plt.ylabel("Eigenvector Values")
plt.legend()
plt.grid(True)
plt.show()
